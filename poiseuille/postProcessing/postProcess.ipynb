# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('pressure.csv')

# %%
df = data.copy()
df = df.rename(columns={'Column1': 'X', 'Column2': 'Pressure'})
df
# Out:
#            X      Pressure
# 0    0.00000  1.461730e+00
# 1    0.10101  1.455800e+00
# 2    0.20202  1.436870e+00
# 3    0.30303  1.409260e+00
# 4    0.40404  1.377590e+00
# ..       ...           ...
# 95   9.59596  4.913250e-02
# 96   9.69697  3.684950e-02
# 97   9.79798  2.456640e-02
# 98   9.89899  1.228310e-02
# 99  10.00000  2.159510e-16
#
# [100 rows x 2 columns]

# %%
plt.style.use("dark_background")
plt.figure()
df.plot(x = 'X', y = 'Pressure', kind='line', color='yellow')
plt.title('Pressure along X axis')
plt.xlabel('X')
plt.ylabel('Pressure')
plt.grid(True, which='both', axis='both', linestyle='--', linewidth=0.5, color='gray')
plt.show()

# %%
u_df = pd.read_csv('velocity.csv')
u_df = u_df.drop(['Column3', 'Column4'], axis=1)
u_df = u_df.rename(columns={'Column1':'X', 'Column2': 'Velocity'})
u_df
# Out:
#            X  Velocity
# 0    0.00000   1.00000
# 1    0.10101   1.00738
# 2    0.20202   1.02756
# 3    0.30303   1.05572
# 4    0.40404   1.08703
# ..       ...       ...
# 95   9.59596   1.48846
# 96   9.69697   1.48846
# 97   9.79798   1.48846
# 98   9.89899   1.48846
# 99  10.00000   1.48846
#
# [100 rows x 2 columns]

# %%
plt.style.use("dark_background")
plt.figure()
u_df.plot(x = 'X', y = 'Velocity', kind='line', color='yellow')
plt.title('Velocity along X axis')
plt.xlabel('X')
plt.ylabel('Pressure')
plt.grid(True, which='both', axis='both', linestyle='--', linewidth=0.5, color='gray')
plt.show()

# %%
p_data = pd.read_csv('pressure_y.csv')
p_df = pd.DataFrame(p_data)
p_df.head(3)
# Out:
#     Column1   Column2
# 0 -0.494949  0.121601
# 1 -0.474747  0.121601
# 2 -0.454545  0.121601

# %%
p_df = p_df.rename(columns={'Column1': 'Y', 'Column2': 'Pressure'})
p_df.head(3)
# Out:
#           Y  Pressure
# 0 -0.494949  0.121601
# 1 -0.474747  0.121601
# 2 -0.454545  0.121601

# %%
plt.style.use("dark_background")
plt.figure()
p_df.plot(x = 'Y', y = 'Pressure', kind='line', color='yellow')
plt.title('Pressure along the line X = 9')
plt.xlabel('Y')
plt.ylabel('Pressure')
plt.grid(True, which='both', axis='both', linestyle='--', linewidth=0.5, color='gray')
plt.show()

# %%
u_data = pd.read_csv('velocity_y.csv')
u_df_y = pd.DataFrame(u_data)
u_df_y = u_df_y.drop(['Column3', 'Column4'], axis=1)
u_df_y.head(3)
# Out:
#     Column1   Column2
# 0 -0.494949  0.030399
# 1 -0.474747  0.149484
# 2 -0.454545  0.263543

# %%
u_df_y = u_df_y.rename(columns={'Column1': 'Y', 'Column2': 'Velocity'})

# %%
plt.style.use("dark_background")
plt.figure()
u_df_y.plot(x = 'Y', y = 'Velocity', kind='line', color='yellow')
plt.title('Velocity along the line X = 9')
plt.xlabel('Y')
plt.ylabel('Velocity')
plt.grid(True, which='both', axis='both', linestyle='--', linewidth=0.5, color='gray')
plt.show()
